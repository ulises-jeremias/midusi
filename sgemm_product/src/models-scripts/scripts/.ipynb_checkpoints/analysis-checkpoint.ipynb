# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('../../../data/filtered_sgemm_product.csv')

# %%
print("Data size",data.shape)
# Out:
# Data size (16224, 13)

# %%
data["Run"].plot.box()

# %%
data.nlargest(10,"Run")
# Out:
#        MWG  NWG  KWG  MDIMC  NDIMC  MDIMA  NDIMB  KWI  VWM  VWN  STRM  STRN  \
# 10460  128  128   32      8      8     16      8    8    2    2     0     0
# 10344  128  128   32      8      8      8     32    8    2    2     0     0
# 10588  128  128   32      8      8     16     16    8    2    2     0     0
# 10892  128  128   32      8      8     32     16    8    2    2     0     0
# 10972  128  128   32      8      8     32     32    8    2    2     0     0
# 10696  128  128   32      8      8     16     32    8    2    2     0     0
# 10108  128  128   32      8      8      8      8    8    2    2     0     0
# 10796  128  128   32      8      8     32      8    8    2    2     0     0
# 10236  128  128   32      8      8      8     16    8    2    2     0     0
# 10133  128  128   32      8      8      8      8    8    4    8     0     1
#
#              Run
# 10460  3341.5075
# 10344  3339.4675
# 10588  3335.3350
# 10892  3335.1800
# 10972  3334.8375
# 10696  3334.4475
# 10108  3324.8200
# 10796  3320.4500
# 10236  3319.2500
# 10133  3271.3250

# %%
data.nsmallest(10,"Run")
# Out:
#        MWG  NWG  KWG  MDIMC  NDIMC  MDIMA  NDIMB  KWI  VWM  VWN  STRM  STRN  \
# 9602   128  128   16     16     32     32     32    8    2    4     1     0
# 9603   128  128   16     16     32     32     32    8    2    4     1     1
# 9563   128  128   16     16     32     32     32    2    2    2     1     1
# 9599   128  128   16     16     32     32     32    8    2    2     1     1
# 9567   128  128   16     16     32     32     32    2    2    4     1     1
# 9566   128  128   16     16     32     32     32    2    2    4     1     0
# 9615   128  128   16     16     32     32     32    8    4    4     1     1
# 9614   128  128   16     16     32     32     32    8    4    4     1     0
# 14759  128  128   32     16     32     16     16    8    2    4     1     1
# 9987   128  128   16     32     16     32     32    2    4    4     1     1
#
#            Run
# 9602   13.3175
# 9603   13.4200
# 9563   13.7400
# 9599   14.4475
# 9567   14.8500
# 9566   14.8550
# 9615   14.9800
# 9614   14.9850
# 14759  15.2475
# 9987   15.3700

# %%
data[data.columns[1:]].corr()['Run'][:-1]
# Out:
# NWG      0.477818
# KWG     -0.026770
# MDIMC   -0.353622
# NDIMC   -0.352976
# MDIMA   -0.067871
# NDIMB   -0.063537
# KWI      0.105920
# VWM      0.143235
# VWN      0.127151
# STRM     0.000838
# STRN     0.002546
# Name: Run, dtype: float64
